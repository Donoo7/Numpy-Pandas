# %%
import pandas as pd
a = [3,4,556,7,]
var = pd.Series(a)
var
# Out:
# 0      3
# 1      4
# 2    556
# 3      7
# dtype: int64

# %%
var = pd.Series(a, index=["monday","tuesday","wednesday","thursday"])
var
# Out:
# monday         3
# tuesday        4
# wednesday    556
# thursday       7
# dtype: int64

# %%
values = {'pen':10, 'book':40, 'pencil':5}
res = pd.Series(values)
res
# Out:
# pen       10
# book      40
# pencil     5
# dtype: int64

# %%
data = {
    "cal":[400,3000,1000], "time":[30,100,50]}
df = pd.DataFrame(data)
df
# Out:
#     cal  time
# 0   400    30
# 1  3000   100
# 2  1000    50

# %%
pd.options.display.max_rows = 10000
df =pd.read_csv('Maternal Health Risk Data Set.csv')
df
# Out:
#       Age  SystolicBP  DiastolicBP     BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.00      98.0         86  high risk
# 1      35         140           90  13.00      98.0         70  high risk
# 2      29          90           70   8.00     100.0         80  high risk
# 3      30         140           85   7.00      98.0         70  high risk
# 4      35         120           60   6.10      98.0         76   low risk
# 5      23         140           80   7.01      98.0         70  high risk
# 6      23         130           70   7.01      98.0         78   mid risk
# 7      35          85           60  11.00     102.0         86  high risk
# 8      32         120           90   6.90      98.0         70   mid risk
# 9      42         130           80  18.00      98.0         70  high risk
# 10     23          90           60   7.01      98.0         76   low risk
# 11     19         120           80   7.00      98.0         70   mid risk
# ...

# %%
df.head(100)
# Out:
#     Age  SystolicBP  DiastolicBP     BS  BodyTemp  HeartRate  RiskLevel
# 0    25         130           80  15.00      98.0         86  high risk
# 1    35         140           90  13.00      98.0         70  high risk
# 2    29          90           70   8.00     100.0         80  high risk
# 3    30         140           85   7.00      98.0         70  high risk
# 4    35         120           60   6.10      98.0         76   low risk
# 5    23         140           80   7.01      98.0         70  high risk
# 6    23         130           70   7.01      98.0         78   mid risk
# 7    35          85           60  11.00     102.0         86  high risk
# 8    32         120           90   6.90      98.0         70   mid risk
# 9    42         130           80  18.00      98.0         70  high risk
# 10   23          90           60   7.01      98.0         76   low risk
# 11   19         120           80   7.00      98.0         70   mid risk
# ...

# %%
df.tail()
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk

# %%
data = {
    "rec":{
        "0":101,
        "1":102,
        "2":205
    },
    "hsplt":{
        "0":"lissi",
        "1":"mth",
        "2":"kj"
    },
    "fund":{
        "0":4000,
        "1":4500,
        "2":3200
    }
}
dff = pd.DataFrame(data)
dff
# Out:
#    rec  hsplt  fund
# 0  101  lissi  4000
# 1  102    mth  4500
# 2  205     kj  3200
